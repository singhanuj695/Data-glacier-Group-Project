# %%
import os.path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline
sns.set()
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading the data

# %%
bank_additional_full = pd.read_csv('bank-additional-full.csv', delimiter=";")
bank_additional_full.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
bank_additional_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
num_features = bank_additional_full.select_dtypes(exclude='object').columns.values
cat_features = bank_additional_full.select_dtypes(include='object').columns.values
print(f"Number of numerical features: {len(num_features)}")
print(f"Number of categorical features: {len(cat_features)}")
# Out:
# Number of numerical features: 10
# Number of categorical features: 11

# %% [markdown]
# ## Dealing with numerical features: Yash Doshi &

# %%
# Making a copy of the dataframe
df_copy1 = bank_additional_full.copy()

# %% [markdown]
# ### 1. Checking correlation between features

# %%
#Label encoding target variable ('y') to include it in correlation matrix
df_copy1['y'].replace({'no':0, 'yes':1},inplace=True)

# %%
# Making correlation matrix and heatmap
corr_matrix = df_copy1.corr()
plt.figure(figsize=(16,10))
sns.heatmap(corr_matrix, cmap="coolwarm", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Observations:
# - euribor3m, emp.var.rate, and nr. employed are heavily correlated with each other. These can be reduced to one feature.

# %% [markdown]
# ### 2. Checking distributions for each feature

# %%
# Plotting boxplots for each numerical feature
fig = plt.figure(figsize=(20,10))
c=1
for feature in num_features:
    fig.add_subplot(3,4,c).set_title(feature)
    sns.boxplot(bank_additional_full[feature])
    c+=1

# %%
# Plotting distribution of each feature
fig = plt.figure(figsize=(20,10))
c=1
for feature in num_features:
    fig.add_subplot(3,4,c)
    sns.distplot(bank_additional_full[feature])
    c+=1

# %% [markdown]
# ## Dealing with categorical features: Harold & Yash

# %% [markdown]
# ### 1. Checking for unknown values

# %%
for cat_feature in cat_features:
    if "unknown" in bank_additional_full[cat_feature].value_counts():
        print(f'count of unknown in {cat_feature}: {bank_additional_full[cat_feature].value_counts()["unknown"]}')
        print(f'% of unknown in {cat_feature}: {(bank_additional_full[cat_feature].value_counts()["unknown"]/bank_additional_full.shape[0])*100:.3f}%')
        print("-----------------------------------------------------------------")
# Out:
# count of unknown in job: 330
# % of unknown in job: 0.801%
# -----------------------------------------------------------------
# count of unknown in marital: 80
# % of unknown in marital: 0.194%
# -----------------------------------------------------------------
# count of unknown in education: 1731
# % of unknown in education: 4.203%
# -----------------------------------------------------------------
# count of unknown in default: 8597
# % of unknown in default: 20.873%
# -----------------------------------------------------------------
# count of unknown in housing: 990
# % of unknown in housing: 2.404%
# -----------------------------------------------------------------
# count of unknown in loan: 990
# % of unknown in loan: 2.404%
# -----------------------------------------------------------------

# %% [markdown]
# ## Mode imputation for unknown values (Yash Jadwani)

# %%
## Making a copy of a dataset for replacing N/A or unknown 

bank_additional_data = bank_additional_full.copy()

# %%
## Replacing uknown in feature with null
bank_additional_data.replace('unknown', np.nan, inplace=True)

# %%
## Deleteing duplicate entries
print('Duplicate entries in the dataset :',bank_additional_data.duplicated().sum())
bank_additional_data.drop_duplicates(inplace=True)
print('Duplicate entries in the dataset After Deletion :',bank_additional_data.duplicated().sum())
# Out:
# Duplicate entries in the dataset : 12
# Duplicate entries in the dataset After Deletion : 0

# %%
bank_additional_data.isnull().sum()
# Out:
# age                  0
# job                330
# marital             80
# education         1730
# default           8596
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# dtype: int64

# %%
bank_additional_data[(bank_additional_data.job.isnull()) & (bank_additional_data.default.isnull()) & (bank_additional_data.housing.isnull())]
# Out:
#        age  job  marital          education default housing loan    contact  \
# 29      55  NaN  married  university.degree     NaN     NaN  NaN  telephone
# 1915    44  NaN   single           basic.9y     NaN     NaN  NaN  telephone
# 2723    45  NaN  married                NaN     NaN     NaN  NaN  telephone
# 21556   44  NaN  married                NaN     NaN     NaN  NaN   cellular
#
#       month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 29      may         mon  ...         1    999         0  nonexistent
# 1915    may         fri  ...         2    999         0  nonexistent
# 2723    may         wed  ...         1    999         0  nonexistent
# 21556   aug         tue  ...         1    999         0  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 29             1.1          93.994          -36.4      4.857       5191.0  no
# 1915           1.1          93.994          -36.4      4.855       5191.0  no
# 2723           1.1          93.994          -36.4      4.859       5191.0  no
# 21556          1.4          93.444          -36.1      4.963       5228.1  no
#
# [4 rows x 21 columns]

# %%
## Removing all the rows where Job, Default and Housing are null

bank_additional_data = bank_additional_data.drop(bank_additional_data[(bank_additional_data.job.isnull()) & (bank_additional_data.default.isnull()) & (bank_additional_data.housing.isnull())].index)
bank_additional_data[(bank_additional_data.job.isnull()) & (bank_additional_data.default.isnull()) & (bank_additional_data.housing.isnull())]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
bank_additional_data[(bank_additional_data.job.isnull()) & (bank_additional_data.education.isnull())]
# Out:
#        age  job   marital education default housing loan    contact month  \
# 73      57  NaN   married       NaN     NaN      no   no  telephone   may
# 91      57  NaN   married       NaN     NaN     yes   no  telephone   may
# 299     38  NaN   married       NaN     NaN      no   no  telephone   may
# 303     43  NaN   married       NaN      no     yes   no  telephone   may
# 343     57  NaN   married       NaN     NaN     yes   no  telephone   may
# ...    ...  ...       ...       ...     ...     ...  ...        ...   ...
# 40289   76  NaN   married       NaN      no      no   no  telephone   jul
# 40370   59  NaN   married       NaN      no      no   no   cellular   aug
# 40428   64  NaN   married       NaN      no     yes   no  telephone   aug
# 40656   67  NaN  divorced       NaN     NaN     yes   no   cellular   sep
# 41108   64  NaN   married       NaN      no      no   no   cellular   nov
#
#       day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 73            mon  ...         1    999         0  nonexistent          1.1
# 91            mon  ...         1    999         0  nonexistent          1.1
# 299           mon  ...         4    999         0  nonexistent          1.1
# 303           mon  ...         2    999         0  nonexistent          1.1
# 343           mon  ...         2    999         0  nonexistent          1.1
# ...           ...  ...       ...    ...       ...          ...          ...
# 40289         thu  ...         3    999         0  nonexistent         -1.7
# 40370         wed  ...         1      6         1      success         -1.7
# 40428         fri  ...         4    999         0  nonexistent         -1.7
# 40656         wed  ...         2      6         2      success         -1.1
# 41108         mon  ...         1      3         3      success         -1.1
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 73             93.994          -36.4      4.857       5191.0   no
# 91             93.994          -36.4      4.857       5191.0   no
# 299            93.994          -36.4      4.857       5191.0   no
# 303            93.994          -36.4      4.857       5191.0   no
# 343            93.994          -36.4      4.857       5191.0   no
# ...               ...            ...        ...          ...  ...
# 40289          94.215          -40.3      0.899       4991.6  yes
# 40370          94.027          -38.3      0.900       4991.6  yes
# 40428          94.027          -38.3      0.905       4991.6  yes
# 40656          94.199          -37.5      0.880       4963.6  yes
# 41108          94.767          -50.8      1.048       4963.6   no
#
# [129 rows x 21 columns]

# %%
## Removing all the rows where Job, Education are null.

bank_additional_data = bank_additional_data.drop(bank_additional_data[(bank_additional_data.job.isnull()) & (bank_additional_data.education.isnull())].index)
bank_additional_data[(bank_additional_data.job.isnull()) & (bank_additional_data.education.isnull())]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Imputation in Marital Status

# %%
bank_additional_data[bank_additional_data.marital.isnull()]
# Out:
#        age           job marital          education default housing loan  \
# 40      58    management     NaN  university.degree      no     yes   no
# 390     59       retired     NaN  university.degree     NaN      no   no
# 413     57       retired     NaN           basic.4y      no      no   no
# 1493    33      services     NaN        high.school      no     yes  yes
# 1608    32           NaN     NaN  university.degree      no      no   no
# ...    ...           ...     ...                ...     ...     ...  ...
# 38550   31  entrepreneur     NaN  university.degree      no      no   no
# 38579   31  entrepreneur     NaN  university.degree      no     yes   no
# 39322   30    technician     NaN  university.degree      no      no   no
# 39323   30    technician     NaN  university.degree      no      no   no
# 40857   30    technician     NaN  university.degree      no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 40     telephone   may         mon  ...         1    999         0
# 390    telephone   may         tue  ...         1    999         0
# 413    telephone   may         tue  ...         1    999         0
# 1493   telephone   may         thu  ...         2    999         0
# 1608   telephone   may         fri  ...         4    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 38550   cellular   oct         thu  ...         1    999         0
# 38579  telephone   oct         thu  ...         4    999         1
# 39322   cellular   mar         mon  ...         2     11         2
# 39323   cellular   mar         mon  ...         2      6         2
# 40857   cellular   oct         fri  ...         2     16         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 40     nonexistent          1.1          93.994          -36.4      4.857
# 390    nonexistent          1.1          93.994          -36.4      4.857
# 413    nonexistent          1.1          93.994          -36.4      4.857
# 1493   nonexistent          1.1          93.994          -36.4      4.855
# 1608   nonexistent          1.1          93.994          -36.4      4.855
# ...            ...          ...             ...            ...        ...
# 38550  nonexistent         -3.4          92.431          -26.9      0.722
# 38579      failure         -3.4          92.431          -26.9      0.722
# 39322      success         -1.8          93.369          -34.8      0.639
# 39323      success         -1.8          93.369          -34.8      0.639
# 40857      success         -1.1          94.601          -49.5      0.942
#
#        nr.employed    y
# 40          5191.0   no
# 390         5191.0   no
# 413         5191.0   no
# 1493        5191.0   no
# 1608        5191.0  yes
# ...            ...  ...
# 38550       5017.5  yes
# 38579       5017.5   no
# 39322       5008.7  yes
# 39323       5008.7  yes
# 40857       4963.6   no
#
# [75 rows x 21 columns]

# %%
### Impuation of marital status based on age by creating age marital map

age_marital_map = bank_additional_data.groupby('age')['marital'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None).to_dict()
bank_additional_data['marital'] = bank_additional_data.apply(lambda row: age_marital_map.get(row['age']) if pd.isna(row['marital']) else row['marital'], axis=1)


bank_additional_data.marital.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Imputation in jobs

# %%
bank_additional_data[bank_additional_data.job.isnull()]
# Out:
#        age  job   marital            education default housing loan  \
# 35      55  NaN   married             basic.4y     NaN     yes   no
# 144     38  NaN  divorced          high.school     NaN     yes   no
# 794     28  NaN    single             basic.9y     NaN      no   no
# 878     28  NaN    single             basic.9y     NaN     yes   no
# 885     43  NaN   married          high.school     NaN      no   no
# ...    ...  ...       ...                  ...     ...     ...  ...
# 40058   57  NaN   married             basic.4y      no     yes   no
# 40208   54  NaN   married             basic.9y      no     yes   no
# 40240   42  NaN    single    university.degree      no      no   no
# 40244   42  NaN    single    university.degree      no     yes   no
# 41005   63  NaN   married  professional.course      no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 35     telephone   may         mon  ...         1    999         0
# 144    telephone   may         mon  ...         1    999         0
# 794    telephone   may         wed  ...         1    999         0
# 878    telephone   may         wed  ...         2    999         0
# 885    telephone   may         wed  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 40058   cellular   jul         wed  ...         3    999         0
# 40208   cellular   jul         tue  ...         2     13         2
# 40240   cellular   jul         fri  ...         6    999         0
# 40244   cellular   jul         fri  ...         1    999         2
# 41005   cellular   oct         thu  ...         1      6         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 35     nonexistent          1.1          93.994          -36.4      4.857
# 144    nonexistent          1.1          93.994          -36.4      4.857
# 794    nonexistent          1.1          93.994          -36.4      4.856
# 878    nonexistent          1.1          93.994          -36.4      4.856
# 885    nonexistent          1.1          93.994          -36.4      4.856
# ...            ...          ...             ...            ...        ...
# 40058  nonexistent         -1.7          94.215          -40.3      0.802
# 40208      success         -1.7          94.215          -40.3      0.876
# 40240  nonexistent         -1.7          94.215          -40.3      0.885
# 40244      failure         -1.7          94.215          -40.3      0.885
# 41005      success         -1.1          94.601          -49.5      1.025
#
#        nr.employed    y
# 35          5191.0   no
# 144         5191.0   no
# 794         5191.0   no
# 878         5191.0   no
# 885         5191.0   no
# ...            ...  ...
# 40058       4991.6   no
# 40208       4991.6   no
# 40240       4991.6  yes
# 40244       4991.6  yes
# 41005       4963.6   no
#
# [197 rows x 21 columns]

# %%
### Impuation of Job based on age and education by creating age,education, and job map
age_edu_job_map = bank_additional_data.groupby(['age', 'education'])['job'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None).to_dict()
bank_additional_data['job'] = bank_additional_data.apply(lambda row: age_edu_job_map.get((row['age'], row['education'])) if pd.isna(row['job']) else row['job'], axis=1)

bank_additional_data.job.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Imputation in Education

# %%
bank_additional_data[bank_additional_data.education.isnull()]
# Out:
#        age          job  marital education default housing loan    contact  \
# 7       41  blue-collar  married       NaN     NaN      no   no  telephone
# 10      41  blue-collar  married       NaN     NaN      no   no  telephone
# 26      59   technician  married       NaN      no     yes   no  telephone
# 30      46       admin.  married       NaN      no      no   no  telephone
# 31      59   technician  married       NaN      no     yes   no  telephone
# ...    ...          ...      ...       ...     ...     ...  ...        ...
# 41118   34   technician  married       NaN      no     yes   no   cellular
# 41120   60       admin.  married       NaN      no      no   no   cellular
# 41122   34   technician  married       NaN      no      no   no   cellular
# 41135   54   technician  married       NaN      no     yes   no   cellular
# 41175   34      student   single       NaN      no     yes   no   cellular
#
#       month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 7       may         mon  ...         1    999         0  nonexistent
# 10      may         mon  ...         1    999         0  nonexistent
# 26      may         mon  ...         1    999         0  nonexistent
# 30      may         mon  ...         1    999         0  nonexistent
# 31      may         mon  ...         1    999         0  nonexistent
# ...     ...         ...  ...       ...    ...       ...          ...
# 41118   nov         tue  ...         2    999         2      failure
# 41120   nov         tue  ...         2    999         0  nonexistent
# 41122   nov         tue  ...         3    999         0  nonexistent
# 41135   nov         thu  ...         1    999         1      failure
# 41175   nov         thu  ...         1    999         2      failure
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 7              1.1          93.994          -36.4      4.857       5191.0   no
# 10             1.1          93.994          -36.4      4.857       5191.0   no
# 26             1.1          93.994          -36.4      4.857       5191.0   no
# 30             1.1          93.994          -36.4      4.857       5191.0   no
# 31             1.1          93.994          -36.4      4.857       5191.0   no
# ...            ...             ...            ...        ...          ...  ...
# 41118         -1.1          94.767          -50.8      1.046       4963.6   no
# 41120         -1.1          94.767          -50.8      1.046       4963.6   no
# 41122         -1.1          94.767          -50.8      1.046       4963.6  yes
# 41135         -1.1          94.767          -50.8      1.041       4963.6   no
# 41175         -1.1          94.767          -50.8      1.031       4963.6   no
#
# [1599 rows x 21 columns]

# %%
### Impuation of Education based on Job by creating education and job map

job_education_map = bank_additional_data.groupby(['job'])['education'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None).to_dict()
bank_additional_data['education'] = bank_additional_data.apply(lambda row: job_education_map.get((row['job'])) if pd.isna(row['education']) else row['education'], axis=1)

bank_additional_data.education.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Imputation of Default, Housing and Loan

# %%
bank_additional_data[(bank_additional_data.loan.isnull()) & (bank_additional_data.default.isnull()) & (bank_additional_data.housing.isnull())]
# Out:
#        age            job  marital            education default housing loan  \
# 81      51    blue-collar  married             basic.4y     NaN     NaN  NaN
# 385     59     management  married             basic.4y     NaN     NaN  NaN
# 401     48       services  married          high.school     NaN     NaN  NaN
# 470     42     technician   single  professional.course     NaN     NaN  NaN
# 494     32         admin.   single    university.degree     NaN     NaN  NaN
# ...    ...            ...      ...                  ...     ...     ...  ...
# 34618   33    blue-collar  married             basic.9y     NaN     NaN  NaN
# 34826   59     management  married             basic.4y     NaN     NaN  NaN
# 34970   42  self-employed  married  professional.course     NaN     NaN  NaN
# 37661   71        retired  married             basic.4y     NaN     NaN  NaN
# 40941   66        retired  married             basic.4y     NaN     NaN  NaN
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 81     telephone   may         mon  ...         1    999         0
# 385    telephone   may         tue  ...         1    999         0
# 401    telephone   may         tue  ...         1    999         0
# 470    telephone   may         tue  ...         1    999         0
# 494    telephone   may         tue  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 34618   cellular   may         thu  ...         2    999         0
# 34826   cellular   may         thu  ...         4    999         1
# 34970   cellular   may         fri  ...         1    999         0
# 37661   cellular   aug         tue  ...         1    999         0
# 40941   cellular   oct         wed  ...         1      6         3
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 81     nonexistent          1.1          93.994          -36.4      4.857
# 385    nonexistent          1.1          93.994          -36.4      4.857
# 401    nonexistent          1.1          93.994          -36.4      4.857
# 470    nonexistent          1.1          93.994          -36.4      4.857
# 494    nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 34618  nonexistent         -1.8          92.893          -46.2      1.266
# 34826      failure         -1.8          92.893          -46.2      1.266
# 34970  nonexistent         -1.8          92.893          -46.2      1.250
# 37661  nonexistent         -2.9          92.201          -31.4      0.859
# 40941      success         -1.1          94.601          -49.5      0.985
#
#        nr.employed    y
# 81          5191.0   no
# 385         5191.0   no
# 401         5191.0   no
# 470         5191.0   no
# 494         5191.0   no
# ...            ...  ...
# 34618       5099.1   no
# 34826       5099.1   no
# 34970       5099.1   no
# 37661       5076.2  yes
# 40941       4963.6  yes
#
# [223 rows x 21 columns]

# %%
bank_additional_data = bank_additional_data.drop(bank_additional_data[(bank_additional_data.loan.isnull()) & (bank_additional_data.default.isnull()) & (bank_additional_data.housing.isnull())].index)
bank_additional_data[(bank_additional_data.loan.isnull()) & (bank_additional_data.default.isnull()) & (bank_additional_data.housing.isnull())]

## Removed all the rows where Loan, Housing,and defualt are null.
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
bank_additional_data.isnull().sum()
# Out:
# age                  0
# job                  0
# marital              0
# education            0
# default           8297
# housing            763
# loan               763
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# dtype: int64

# %% [markdown]
# #### Default

# %%
bank_additional_data.default.value_counts()
# Out:
# no     32520
# yes        3
# Name: default, dtype: int64

# %% [markdown]
# The given dataset contains information on whether individuals have defaulted on their payments or not. After analyzing the data, it was found that out of the total 32523 records, only 3 individuals had defaulted. This suggests that the vast majority of individuals in the dataset have not defaulted on their payments. Therefore, we removed the default feature from the analysis as it may not be useful in making any meaningful conclusions.

# %%
## removing the defualt column
bank_additional_data.drop('default',axis=1,inplace=True)

# %% [markdown]
# #### Loan

# %%
print('Value count of loan before imputation:')
print(bank_additional_data.loan.value_counts())
# Out:
# Value count of loan before imputation:
# no     33827
# yes     6230
# Name: loan, dtype: int64

# %%
## Impuation of loan based on Marital Status, Job and Education by creating loan, Marital Status, Job and Education map

loan_map = bank_additional_data.groupby(['marital','job','education'])['loan'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None).to_dict()
bank_additional_data['loan'] = bank_additional_data.apply(lambda row: loan_map.get((row['marital'],row['job'],row['education'])) if pd.isna(row['loan']) else row['loan'], axis=1)

bank_additional_data.loan.isnull().sum()
# Out:
# 0

# %%
print('Value count of loan after imputation:')
print(bank_additional_data.loan.value_counts())
# Out:
# Value count of loan after imputation:
# no     34590
# yes     6230
# Name: loan, dtype: int64

# %% [markdown]
# #### Housing

# %%
print('Value count of housing before imputation:')
print(bank_additional_data.housing.value_counts())
# Out:
# Value count of housing before imputation:
# yes    21495
# no     18562
# Name: housing, dtype: int64

# %%
## Impuation of housing based on Marital Status, Job and Education by creating housing, Marital Status, Job and Education map

housing_map = bank_additional_data.groupby(['marital','job','education'])['housing'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None).to_dict()
bank_additional_data['housing'] = bank_additional_data.apply(lambda row: housing_map.get((row['marital'],row['job'],row['education'])) if pd.isna(row['housing']) else row['housing'], axis=1)

bank_additional_data.housing.isnull().sum()
# Out:
# 0

# %%
print('Value count of housing after imputation:')
print(bank_additional_data.housing.value_counts())
# Out:
# Value count of housing after imputation:
# yes    22195
# no     18625
# Name: housing, dtype: int64

# %%
bank_additional_data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
bank_additional_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40820 entries, 0 to 41187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             40820 non-null  int64
#  1   job             40820 non-null  object
#  2   marital         40820 non-null  object
#  3   education       40820 non-null  object
#  4   housing         40820 non-null  object
#  5   loan            40820 non-null  object
#  6   contact         40820 non-null  object
#  7   month           40820 non-null  object
#  8   day_of_week     40820 non-null  object
#  9   duration        40820 non-null  int64
#  10  campaign        40820 non-null  int64
#  11  pdays           40820 non-null  int64
#  12  previous        40820 non-null  int64
#  13  poutcome        40820 non-null  object
#  14  emp.var.rate    40820 non-null  float64
#  15  cons.price.idx  40820 non-null  float64
#  16  cons.conf.idx   40820 non-null  float64
#  17  euribor3m       40820 non-null  float64
#  18  nr.employed     40820 non-null  float64
#  19  y               40820 non-null  object
# dtypes: float64(5), int64(5), object(10)
# memory usage: 6.5+ MB

# %%
fig, axs = plt.subplots(1, 2)

axs[0].pie(bank_additional_full['y'].value_counts(),labels = bank_additional_full['y'].value_counts().index.tolist(), autopct='%1.2f%%',explode=[0.05]*2)
axs[0].set_title('Target vector before imputation')

axs[1].pie(bank_additional_data['y'].value_counts(),labels = bank_additional_data['y'].value_counts().index.tolist(), autopct='%1.2f%%',explode=[0.05]*2)
axs[1].set_title('Target vector after imputation')

plt.show()
